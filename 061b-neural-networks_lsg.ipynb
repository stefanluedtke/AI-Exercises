# %% [markdown]
# # Neuronale Netze
#
# In this Keras tutorial, you will use the Pima Indians onset of diabetes dataset. This is a standard machine learning dataset from the UCI Machine Learning repository. It describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# As such, it is a binary classification problem (onset of diabetes as 1 or not as 0). All of the input variables that describe each patient are numerical. This makes it easy to use directly with neural networks that expect numerical input and output values and is an ideal choice for our first neural network in Keras.
#
# You can load the file as a matrix of numbers using the NumPy function loadtxt():

# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split


# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
#
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
#
# The first thing to get right is to ensure the input layer has the correct number of input features. This can be specified when creating the first layer with the input_shape argument and setting it to (8,) for presenting the eight input variables as a vector.
#
# How do we know the number of layers and their types?
#
# This is a tricky question. There are heuristics that you can use, and often the best network structure is found through a process of trial and error experimentation. Generally, you need a network large enough to capture the structure of the problem.
#
# In this example, let’s use a fully-connected network structure with three layers.
#
# Fully connected layers are defined using the Dense class. You can specify the number of neurons or nodes in the layer as the first argument and the activation function using the activation argument.
#
# Also, you will use the rectified linear unit activation function referred to as ReLU on the first two layers and the Sigmoid function in the output layer.
#
# It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. Using a sigmoid on the output layer ensures your network output is between 0 and 1 and is easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
# Define a model with three layers: a layer with 12 nodes, a layer with 8 nodes and finally an (output) layer with just a single node. Use Relu activation functions in all layers except the last layer, where you should use a sigmoid function.

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
#TODO: Add remaining layers
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Now that the model is defined, you can compile it.
#
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU, GPU, or even distributed.
#
# When compiling, you must specify some additional properties required when training the network. Remember training a network means finding the best set of weights to map inputs to outputs in your dataset.
#
# You must specify the loss function to use to evaluate a set of weights, the optimizer used to search through different weights for the network, and any optional metrics you want to collect and report during training.
#
# In this case, use cross entropy as the loss argument. This loss is for a binary classification problems and is defined in Keras as “binary_crossentropy“.
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm “adam“. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.
#
# Finally, because it is a classification problem, you will collect and report the classification accuracy defined via the metrics argument.
#
# Use the compile()-Function to compile the model:

# %%
#TODO
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# You have defined your model and compiled it to get ready for efficient computation.
#
# Now it is time to execute the model on some data.
#
# You can train or fit your model on your loaded data by calling the fit() function on the model.
#
# Training occurs over epochs, and each epoch is split into batches.
#
#     * Epoch: One pass through all of the rows in the training dataset
#     * Batch: One or more samples considered by the model within an epoch before weights are updated
#
# One epoch comprises one or more batches, based on the chosen batch size, and the model is fit for many epochs.
#
# The training process will run for a fixed number of epochs (iterations) through the dataset that you must specify using the epochs argument. You must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size, and set using the batch_size argument.
#
# Fit the model with 150 epochs and a batch size of 10.

# %%
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 58/58 [==============================] - 0s 622us/step - loss: 6.0206 - accuracy: 0.5764
# Epoch 2/150
# 58/58 [==============================] - 0s 637us/step - loss: 1.9921 - accuracy: 0.4792
# Epoch 3/150
# 58/58 [==============================] - 0s 590us/step - loss: 1.6242 - accuracy: 0.5017
# Epoch 4/150
# 58/58 [==============================] - 0s 591us/step - loss: 1.3826 - accuracy: 0.5260
# Epoch 5/150
# 58/58 [==============================] - 0s 598us/step - loss: 1.1367 - accuracy: 0.5521
# Epoch 6/150
# 58/58 [==============================] - 0s 624us/step - loss: 0.9699 - accuracy: 0.5868
# Epoch 7/150
# 58/58 [==============================] - 0s 580us/step - loss: 0.8420 - accuracy: 0.6059
# Epoch 8/150
# 58/58 [==============================] - 0s 593us/step - loss: 0.7825 - accuracy: 0.5938
# Epoch 9/150
# 58/58 [==============================] - 0s 597us/step - loss: 0.7020 - accuracy: 0.6198
# Epoch 10/150
# 58/58 [==============================] - 0s 626us/step - loss: 0.7282 - accuracy: 0.6319
# Epoch 11/150
# 58/58 [==============================] - 0s 582us/step - loss: 0.6514 - accuracy: 0.6806
# Epoch 12/150
# 58/58 [==============================] - 0s 611us/step - loss: 0.6728 - accuracy: 0.6545
# Epoch 13/150
# 58/58 [==============================] - 0s 600us/step - loss: 0.6163 - accuracy: 0.7066
# Epoch 14/150
# 58/58 [==============================] - 0s 597us/step - loss: 0.6167 - accuracy: 0.6823
# Epoch 15/150
# 58/58 [==============================] - 0s 618us/step - loss: 0.6047 - accuracy: 0.6927
# Epoch 16/150
# 58/58 [==============================] - 0s 585us/step - loss: 0.6225 - accuracy: 0.6736
# Epoch 17/150
# 58/58 [==============================] - 0s 586us/step - loss: 0.6243 - accuracy: 0.6788
# Epoch 18/150
# 58/58 [==============================] - 0s 601us/step - loss: 0.6129 - accuracy: 0.6858
# Epoch 19/150
# 58/58 [==============================] - 0s 604us/step - loss: 0.6035 - accuracy: 0.6858
# Epoch 20/150
# 58/58 [==============================] - 0s 622us/step - loss: 0.6196 - accuracy: 0.7066
# Epoch 21/150
# 58/58 [==============================] - 0s 611us/step - loss: 0.6278 - accuracy: 0.6719
# Epoch 22/150
# 58/58 [==============================] - 0s 600us/step - loss: 0.6267 - accuracy: 0.6788
# Epoch 23/150
# 58/58 [==============================] - 0s 603us/step - loss: 0.5921 - accuracy: 0.7274
# Epoch 24/150
# 58/58 [==============================] - 0s 600us/step - loss: 0.5917 - accuracy: 0.6927
# Epoch 25/150
# 58/58 [==============================] - 0s 601us/step - loss: 0.6087 - accuracy: 0.6944
# Epoch 26/150
# 58/58 [==============================] - 0s 605us/step - loss: 0.6065 - accuracy: 0.6927
# Epoch 27/150
# 58/58 [==============================] - 0s 610us/step - loss: 0.5721 - accuracy: 0.7101
# Epoch 28/150
# 58/58 [==============================] - 0s 613us/step - loss: 0.5881 - accuracy: 0.6944
# Epoch 29/150
# 58/58 [==============================] - 0s 590us/step - loss: 0.6483 - accuracy: 0.6684
# Epoch 30/150
# 58/58 [==============================] - 0s 628us/step - loss: 0.6358 - accuracy: 0.6615
# Epoch 31/150
# 58/58 [==============================] - 0s 604us/step - loss: 0.5612 - accuracy: 0.7205
# Epoch 32/150
# 58/58 [==============================] - 0s 589us/step - loss: 0.5840 - accuracy: 0.6875
# Epoch 33/150
# 58/58 [==============================] - 0s 606us/step - loss: 0.5689 - accuracy: 0.7014
# Epoch 34/150
# 58/58 [==============================] - 0s 613us/step - loss: 0.5727 - accuracy: 0.7153
# Epoch 35/150
# 58/58 [==============================] - 0s 624us/step - loss: 0.5707 - accuracy: 0.7014
# Epoch 36/150
# 58/58 [==============================] - 0s 606us/step - loss: 0.5620 - accuracy: 0.7118
# Epoch 37/150
# 58/58 [==============================] - 0s 566us/step - loss: 0.5965 - accuracy: 0.6788
# Epoch 38/150
# 58/58 [==============================] - 0s 565us/step - loss: 0.5734 - accuracy: 0.7083
# Epoch 39/150
# 58/58 [==============================] - 0s 571us/step - loss: 0.5808 - accuracy: 0.6962
# Epoch 40/150
# 58/58 [==============================] - 0s 549us/step - loss: 0.5545 - accuracy: 0.7101
# Epoch 41/150
# 58/58 [==============================] - 0s 546us/step - loss: 0.5920 - accuracy: 0.6892
# Epoch 42/150
# 58/58 [==============================] - 0s 555us/step - loss: 0.5655 - accuracy: 0.7101
# Epoch 43/150
# 58/58 [==============================] - 0s 572us/step - loss: 0.5659 - accuracy: 0.7170
# Epoch 44/150
# 58/58 [==============================] - 0s 552us/step - loss: 0.5459 - accuracy: 0.7274
# Epoch 45/150
# 58/58 [==============================] - 0s 577us/step - loss: 0.5541 - accuracy: 0.6927
# Epoch 46/150
# 58/58 [==============================] - 0s 568us/step - loss: 0.5562 - accuracy: 0.7135
# Epoch 47/150
# 58/58 [==============================] - 0s 570us/step - loss: 0.5432 - accuracy: 0.7205
# Epoch 48/150
# 58/58 [==============================] - 0s 554us/step - loss: 0.5880 - accuracy: 0.7083
# Epoch 49/150
# 58/58 [==============================] - 0s 578us/step - loss: 0.5483 - accuracy: 0.7378
# Epoch 50/150
# 58/58 [==============================] - 0s 586us/step - loss: 0.5630 - accuracy: 0.6997
# Epoch 51/150
# 58/58 [==============================] - 0s 562us/step - loss: 0.5853 - accuracy: 0.7031
# Epoch 52/150
# 58/58 [==============================] - 0s 556us/step - loss: 0.5590 - accuracy: 0.7274
# Epoch 53/150
# 58/58 [==============================] - 0s 577us/step - loss: 0.5599 - accuracy: 0.7309
# Epoch 54/150
# 58/58 [==============================] - 0s 553us/step - loss: 0.5831 - accuracy: 0.7066
# Epoch 55/150
# 58/58 [==============================] - 0s 561us/step - loss: 0.5462 - accuracy: 0.7361
# Epoch 56/150
# 58/58 [==============================] - 0s 578us/step - loss: 0.5893 - accuracy: 0.7135
# Epoch 57/150
# 58/58 [==============================] - 0s 560us/step - loss: 0.5417 - accuracy: 0.7326
# Epoch 58/150
# 58/58 [==============================] - 0s 578us/step - loss: 0.5440 - accuracy: 0.7378
# Epoch 59/150
# 58/58 [==============================] - 0s 562us/step - loss: 0.5756 - accuracy: 0.7101
# Epoch 60/150
# 58/58 [==============================] - 0s 574us/step - loss: 0.5632 - accuracy: 0.7135
# Epoch 61/150
# 58/58 [==============================] - 0s 576us/step - loss: 0.5433 - accuracy: 0.7604
# Epoch 62/150
# 58/58 [==============================] - 0s 550us/step - loss: 0.5810 - accuracy: 0.6979
# Epoch 63/150
# 58/58 [==============================] - 0s 582us/step - loss: 0.5335 - accuracy: 0.7257
# Epoch 64/150
# 58/58 [==============================] - 0s 567us/step - loss: 0.5393 - accuracy: 0.7274
# Epoch 65/150
# 58/58 [==============================] - 0s 579us/step - loss: 0.5657 - accuracy: 0.7135
# Epoch 66/150
# 58/58 [==============================] - 0s 577us/step - loss: 0.5318 - accuracy: 0.7240
# Epoch 67/150
# 58/58 [==============================] - 0s 583us/step - loss: 0.5288 - accuracy: 0.7431
# Epoch 68/150
# 58/58 [==============================] - 0s 569us/step - loss: 0.5351 - accuracy: 0.7569
# Epoch 69/150
# 58/58 [==============================] - 0s 579us/step - loss: 0.5188 - accuracy: 0.7587
# Epoch 70/150
# 58/58 [==============================] - 0s 565us/step - loss: 0.5298 - accuracy: 0.7413
# Epoch 71/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.5415 - accuracy: 0.7170
# Epoch 72/150
# 58/58 [==============================] - 0s 571us/step - loss: 0.5224 - accuracy: 0.7517
# Epoch 73/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.5572 - accuracy: 0.7153
# Epoch 74/150
# 58/58 [==============================] - 0s 578us/step - loss: 0.5312 - accuracy: 0.7378
# Epoch 75/150
# 58/58 [==============================] - 0s 576us/step - loss: 0.5236 - accuracy: 0.7222
# Epoch 76/150
# 58/58 [==============================] - 0s 574us/step - loss: 0.5315 - accuracy: 0.7361
# Epoch 77/150
# 58/58 [==============================] - 0s 563us/step - loss: 0.5206 - accuracy: 0.7431
# Epoch 78/150
# 58/58 [==============================] - 0s 570us/step - loss: 0.5223 - accuracy: 0.7431
# Epoch 79/150
# 58/58 [==============================] - 0s 583us/step - loss: 0.5126 - accuracy: 0.7378
# Epoch 80/150
# 58/58 [==============================] - 0s 588us/step - loss: 0.4999 - accuracy: 0.7569
# Epoch 81/150
# 58/58 [==============================] - 0s 619us/step - loss: 0.5403 - accuracy: 0.7222
# Epoch 82/150
# 58/58 [==============================] - 0s 575us/step - loss: 0.5222 - accuracy: 0.7448
# Epoch 83/150
# 58/58 [==============================] - 0s 595us/step - loss: 0.5160 - accuracy: 0.7639
# Epoch 84/150
# 58/58 [==============================] - 0s 574us/step - loss: 0.5162 - accuracy: 0.7535
# Epoch 85/150
# 58/58 [==============================] - 0s 568us/step - loss: 0.5056 - accuracy: 0.7517
# Epoch 86/150
# 58/58 [==============================] - 0s 569us/step - loss: 0.5476 - accuracy: 0.7396
# Epoch 87/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.5138 - accuracy: 0.7413
# Epoch 88/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.5191 - accuracy: 0.7413
# Epoch 89/150
# 58/58 [==============================] - 0s 576us/step - loss: 0.5137 - accuracy: 0.7552
# Epoch 90/150
# 58/58 [==============================] - 0s 579us/step - loss: 0.5080 - accuracy: 0.7622
# Epoch 91/150
# 58/58 [==============================] - 0s 565us/step - loss: 0.5158 - accuracy: 0.7396
# Epoch 92/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.5113 - accuracy: 0.7413
# Epoch 93/150
# 58/58 [==============================] - 0s 581us/step - loss: 0.4928 - accuracy: 0.7760
# Epoch 94/150
# 58/58 [==============================] - 0s 597us/step - loss: 0.5124 - accuracy: 0.7604
# Epoch 95/150
# 58/58 [==============================] - 0s 590us/step - loss: 0.5333 - accuracy: 0.7517
# Epoch 96/150
# 58/58 [==============================] - 0s 584us/step - loss: 0.4908 - accuracy: 0.7691
# Epoch 97/150
# 58/58 [==============================] - 0s 585us/step - loss: 0.5181 - accuracy: 0.7413
# Epoch 98/150
# 58/58 [==============================] - 0s 611us/step - loss: 0.5154 - accuracy: 0.7326
# Epoch 99/150
# 58/58 [==============================] - 0s 606us/step - loss: 0.5203 - accuracy: 0.7569
# Epoch 100/150
# 58/58 [==============================] - 0s 583us/step - loss: 0.5165 - accuracy: 0.7483
# Epoch 101/150
# 58/58 [==============================] - 0s 585us/step - loss: 0.4902 - accuracy: 0.7726
# Epoch 102/150
# 58/58 [==============================] - 0s 581us/step - loss: 0.5303 - accuracy: 0.7309
# Epoch 103/150
# 58/58 [==============================] - 0s 573us/step - loss: 0.4957 - accuracy: 0.7639
# Epoch 104/150
# 58/58 [==============================] - 0s 581us/step - loss: 0.5005 - accuracy: 0.7587
# Epoch 105/150
# 58/58 [==============================] - 0s 568us/step - loss: 0.4893 - accuracy: 0.7517
# Epoch 106/150
# 58/58 [==============================] - 0s 586us/step - loss: 0.5235 - accuracy: 0.7396
# Epoch 107/150
# 58/58 [==============================] - 0s 569us/step - loss: 0.5104 - accuracy: 0.7361
# Epoch 108/150
# 58/58 [==============================] - 0s 577us/step - loss: 0.5000 - accuracy: 0.7604
# Epoch 109/150
# 58/58 [==============================] - 0s 575us/step - loss: 0.4847 - accuracy: 0.7656
# Epoch 110/150
# 58/58 [==============================] - 0s 596us/step - loss: 0.5196 - accuracy: 0.7552
# Epoch 111/150
# 58/58 [==============================] - 0s 609us/step - loss: 0.5109 - accuracy: 0.7622
# Epoch 112/150
# 58/58 [==============================] - 0s 612us/step - loss: 0.5085 - accuracy: 0.7431
# Epoch 113/150
# 58/58 [==============================] - 0s 601us/step - loss: 0.5031 - accuracy: 0.7448
# Epoch 114/150
# 58/58 [==============================] - 0s 587us/step - loss: 0.4812 - accuracy: 0.7847
# Epoch 115/150
# 58/58 [==============================] - 0s 593us/step - loss: 0.5011 - accuracy: 0.7552
# Epoch 116/150
# 58/58 [==============================] - 0s 594us/step - loss: 0.5165 - accuracy: 0.7396
# Epoch 117/150
# 58/58 [==============================] - 0s 596us/step - loss: 0.4821 - accuracy: 0.7812
# Epoch 118/150
# 58/58 [==============================] - 0s 660us/step - loss: 0.4931 - accuracy: 0.7743
# Epoch 119/150
# 58/58 [==============================] - 0s 608us/step - loss: 0.4743 - accuracy: 0.7865
# Epoch 120/150
# 58/58 [==============================] - 0s 590us/step - loss: 0.4846 - accuracy: 0.7552
# Epoch 121/150
# 58/58 [==============================] - 0s 614us/step - loss: 0.4926 - accuracy: 0.7622
# Epoch 122/150
# 58/58 [==============================] - 0s 596us/step - loss: 0.4910 - accuracy: 0.7639
# Epoch 123/150
# 58/58 [==============================] - 0s 556us/step - loss: 0.4822 - accuracy: 0.7760
# Epoch 124/150
# 58/58 [==============================] - 0s 569us/step - loss: 0.5091 - accuracy: 0.7587
# Epoch 125/150
# 58/58 [==============================] - 0s 566us/step - loss: 0.4848 - accuracy: 0.7517
# Epoch 126/150
# 58/58 [==============================] - 0s 584us/step - loss: 0.4725 - accuracy: 0.7951
# Epoch 127/150
# 58/58 [==============================] - 0s 574us/step - loss: 0.4873 - accuracy: 0.7795
# Epoch 128/150
# 58/58 [==============================] - 0s 568us/step - loss: 0.4937 - accuracy: 0.7760
# Epoch 129/150
# 58/58 [==============================] - 0s 576us/step - loss: 0.5113 - accuracy: 0.7396
# Epoch 130/150
# 58/58 [==============================] - 0s 570us/step - loss: 0.5009 - accuracy: 0.7760
# Epoch 131/150
# 58/58 [==============================] - 0s 580us/step - loss: 0.5275 - accuracy: 0.7587
# Epoch 132/150
# 58/58 [==============================] - 0s 587us/step - loss: 0.4914 - accuracy: 0.7656
# Epoch 133/150
# 58/58 [==============================] - 0s 614us/step - loss: 0.5056 - accuracy: 0.7431
# Epoch 134/150
# 58/58 [==============================] - 0s 604us/step - loss: 0.4842 - accuracy: 0.7726
# Epoch 135/150
# 58/58 [==============================] - 0s 574us/step - loss: 0.4793 - accuracy: 0.7691
# Epoch 136/150
# 58/58 [==============================] - 0s 594us/step - loss: 0.5131 - accuracy: 0.7552
# Epoch 137/150
# 58/58 [==============================] - 0s 603us/step - loss: 0.5594 - accuracy: 0.7483
# Epoch 138/150
# 58/58 [==============================] - 0s 610us/step - loss: 0.4875 - accuracy: 0.7552
# Epoch 139/150
# 58/58 [==============================] - 0s 588us/step - loss: 0.4815 - accuracy: 0.7569
# Epoch 140/150
# 58/58 [==============================] - 0s 593us/step - loss: 0.4948 - accuracy: 0.7292
# Epoch 141/150
# 58/58 [==============================] - 0s 606us/step - loss: 0.4804 - accuracy: 0.7674
# Epoch 142/150
# 58/58 [==============================] - 0s 606us/step - loss: 0.4799 - accuracy: 0.7708
# Epoch 143/150
# 58/58 [==============================] - 0s 609us/step - loss: 0.4689 - accuracy: 0.7622
# Epoch 144/150
# 58/58 [==============================] - 0s 603us/step - loss: 0.4951 - accuracy: 0.7448
# Epoch 145/150
# 58/58 [==============================] - 0s 591us/step - loss: 0.4685 - accuracy: 0.7743
# Epoch 146/150
# 58/58 [==============================] - 0s 604us/step - loss: 0.5231 - accuracy: 0.7535
# Epoch 147/150
# 58/58 [==============================] - 0s 600us/step - loss: 0.4681 - accuracy: 0.7500
# Epoch 148/150
# 58/58 [==============================] - 0s 613us/step - loss: 0.4905 - accuracy: 0.7674
# Epoch 149/150
# 58/58 [==============================] - 0s 568us/step - loss: 0.4903 - accuracy: 0.7587
# Epoch 150/150
# 58/58 [==============================] - 0s 570us/step - loss: 0.4659 - accuracy: 0.7726

# %% [markdown]
# You have trained our neural network on the entire dataset, and you can evaluate the performance of the network on the same dataset.
#
# This will only give you an idea of how well you have modeled the dataset (e.g., train accuracy), but no idea of how well the algorithm might perform on new data. This was done for simplicity, but ideally, you could separate your data into train and test datasets for training and evaluation of your model.
#
# You can evaluate your model on your training dataset using the evaluate() function and pass it the same input and output used to train the model.
#
# This will generate a prediction for each input and output pair and collect scores, including the average loss and any metrics you have configured, such as accuracy.
#
# The evaluate() function will return a list with two values. The first will be the loss of the model on the dataset, and the second will be the accuracy of the model on the dataset. You are only interested in reporting the accuracy so ignore the loss value.

# %%
#TODO
_, accuracy = model.evaluate(X_train, y_train)
print('Train Accuracy: %.2f' % (accuracy*100))

_, accuracy = model.evaluate(X_test, y_test)
print('Test Accuracy: %.2f' % (accuracy*100))
# Out:
# 18/18 [==============================] - 0s 692us/step - loss: 0.4792 - accuracy: 0.7708
# Train Accuracy: 77.08
# 6/6 [==============================] - 0s 842us/step - loss: 0.6147 - accuracy: 0.7188
# Test Accuracy: 71.88

# %% [markdown]
# Now, try to improve the model by changing hyperprameters. What is the best accuracy that you can achieve?
