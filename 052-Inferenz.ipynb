# %% [markdown]
# # Probabilistische Inferenz
#
# ## 1. Bayesian Networks
#
# Consider the following Bayesian network with the conditional probability tables.
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# 1. Express the joint distribution P(B,E,A,J,M) in terms of the conditional independences
# expressed in the Bayesian Network.
# 2. Calculate $P(Burglary|JohnCalls = true, MaryCalls = true)$

# %% [markdown]
# ## 2. Variable Elimination
# Given the below network and factors, use Variable Elimination to find P (A|b).
# ![grafik.png](attachment:grafik.png)
# ![grafik-2.png](attachment:grafik-2.png)
